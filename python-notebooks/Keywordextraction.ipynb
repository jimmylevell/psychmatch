# %%
# !pip install rake-nltk
# !pip install spacy
# !pip install azure-ai-textanalytics
# Out:
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Collecting nltk<4.0.0,>=3.6.2
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 13.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.4.24-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 65.6 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.0)
# Installing collected packages: regex, nltk, rake-nltk
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.7 rake-nltk-1.0.6 regex-2022.4.24
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (4.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Collecting azure-ai-textanalytics
#   Downloading azure_ai_textanalytics-5.1.0-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 17.1 MB/s
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-textanalytics) (1.15.0)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.7 MB/s
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting azure-core<2.0.0,>=1.14.0
#   Downloading azure_core-1.24.0-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 79.3 MB/s
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (2.23.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (4.2.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-textanalytics) (1.3.1)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 735 kB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-textanalytics) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.14.0->azure-ai-textanalytics) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-textanalytics) (3.2.0)
# Installing collected packages: isodate, msrest, azure-core, azure-common, azure-ai-textanalytics
# Successfully installed azure-ai-textanalytics-5.1.0 azure-common-1.1.28 azure-core-1.24.0 isodate-0.6.1 msrest-0.6.21

# %%
import numpy as np
import nltk
import os
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Example Queries

# %%
example_sentence = "BLEU is a standard algorithm for evaluating the machine translations against the human translations. At first I thought it should be very straightforward to use. However, it turns out that there are a lot of caveats."

# %% [markdown]
# ## Spacy

# %%
# based https://betterprogramming.pub/extract-keywords-using-spacy-in-python-4a8415478fbf
# !python -m spacy download en_core_web_lg

import spacy
from collections import Counter
from string import punctuation
import en_core_web_lg

nlp = en_core_web_lg.load()
# Out:
# Collecting en_core_web_lg==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 1.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.21.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (57.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.64.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.9.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180942 sha256=62ba7de7e41d1fc77e7dfc24856f21e79cfa7e8ea92c61849b3d4e6af3f0cbca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-483i7304/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
def extract_spacy(content):
    result = []
    doc = nlp(content.lower())
    
    # only add keywords which are included in the following POS
    pos_tag = ['PROPN', 'ADJ', 'NOUN']
    
    for token in doc:
        if token.text in nlp.Defaults.stop_words or token.text in punctuation:
            continue

        if token.pos_ in pos_tag:
            result.append(token.text)
                
    return result

extract_spacy(example_sentence)
# Out:
# ['bleu',
#  'standard',
#  'algorithm',
#  'machine',
#  'translations',
#  'human',
#  'translations',
#  'straightforward',
#  'lot',
#  'caveats']

# %% [markdown]
# ## Rake

# %%
def extract_rake(content):
  from rake_nltk import Rake

  rake = Rake()
  result = []

  doc = rake.extract_keywords_from_text(content.lower())
  doc = rake.get_ranked_phrases()

  for token in doc:
    if token in nlp.Defaults.stop_words or token in punctuation:
      continue
    result.append(token)

  return result

extract_rake(example_sentence)
# Out:
# ['standard algorithm',
#  'machine translations',
#  'human translations',
#  'use',
#  'turns',
#  'thought',
#  'straightforward',
#  'lot',
#  'evaluating',
#  'caveats',
#  'bleu']

# %% [markdown]
# ## Microsoft Cognitive Services

# %%
def extract_microsoft(content):
  key = "<key>"
  endpoint = "https://psychmatch-textanalytics.cognitiveservices.azure.com/"

  from azure.ai.textanalytics import TextAnalyticsClient
  from azure.core.credentials import AzureKeyCredential

  # Authenticate the client using your key and endpoint 
  def authenticate_client():
      ta_credential = AzureKeyCredential(key)
      text_analytics_client = TextAnalyticsClient(
              endpoint=endpoint, 
              credential=ta_credential)
      return text_analytics_client

  client = authenticate_client()

  def key_phrase_extraction_example(client):
      try:
          response = client.extract_key_phrases(documents = [content])[0]

          if not response.is_error:
            return response.key_phrases
          else:
              print(response.id, response.error)

      except Exception as err:
          print("Encountered exception. {}".format(err))
          
  return key_phrase_extraction_example(client)

extract_microsoft(example_sentence)
# Out:
# ['standard algorithm',
#  'machine translations',
#  'human translations',
#  'BLEU',
#  'lot',
#  'caveats']

# %% [markdown]
# # Spacy and RAKE
# Trying to combine NLP and RAKE to improve the performance of RAKE.

# %%
def extract_spacy_rake(content):
  content = extract_spacy(content)
  content = extract_rake((". ").join(content))

  return content

extract_spacy_rake(example_sentence)
# Out:
# ['bleu', 'standard', 'algorithm', 'machine', 'translations', 'human', 'translations', 'straightforward', 'lot', 'caveats']
# ['translations',
#  'translations',
#  'straightforward',
#  'standard',
#  'machine',
#  'lot',
#  'human',
#  'caveats',
#  'bleu',
#  'algorithm']

# %% [markdown]
# # Loding Test Data

# %%
class KeywordExtraction:
  def __init__(self, name, extractor):
    self.name = name
    self.extractor = extractor
    self.total_precision = 0
    self.total_recall = 0
    self.total_fmeasure = 0

# %%
# variable section
data_dir = '/content/drive/MyDrive/Colab Notebooks/VM2/data/keyword/' # based on https://github.com/bohrjoce/keyword-extraction
number_of_files = 100
filenames = sorted(os.listdir(data_dir))[0:number_of_files + 1]
manual_keywords = []
total_precision = 0
total_recall = 0
total_docs = 0

language = 'english'

# %%
services = [
  KeywordExtraction("spacy", extract_spacy),
  KeywordExtraction("microsoft", extract_microsoft),
  KeywordExtraction("rake", extract_rake),
  KeywordExtraction("spacy_rake", extract_spacy_rake)
]

for filename in filenames:
  print(filename)

  # load golden truth
  if filename[-3:] == 'key':
    # ignored due to issue on Mac or empty keyfile
    if filename == "H-5.key" or filename == "C-86.key":
      continue

    with open(data_dir + filename, 'r') as f:
      last_key_file = filename
      key_lines = f.read().splitlines()

      # list of list of keywords by line and flatten it
      manual_keywords = [line.split() for line in key_lines]
      manual_keywords = [word for line in manual_keywords for word in line]
      manual_keywords = list(set(manual_keywords))
      manual_keywords = [t for t in manual_keywords if ( (len(t) > 1) and (t.lower()not in stopwords.words(language)) )]

  # load sample text
  elif filename[-3:] == 'txt':
    # ignored due to issue on Mac or empty keyfile
    if filename == "H-5.txt" or filename == "C-86.txt":
      continue

    total_docs += 1
    with open(data_dir + filename, 'r') as f:
      for service in services:
        correct = 0
        f = open(data_dir + filename, 'r')
        content = f.read()

        ## apply keyword extraction
        keywords = service.extractor(content[0:5120])
        
        # make unique and flatten
        keywords = list(set(keywords))

        for keyword in keywords:
          if keyword in set(manual_keywords):
            correct += 1
        
        if len(manual_keywords) == 0:
          print(filename)
          print(last_key_file)
          print('^^^^ issue with this file ^^^^')
          exit(0)

        service.total_precision += correct/float(len(keywords))
        service.total_recall += correct/float(len(manual_keywords))
# Out:
# C-1.key
# C-1.txt
# ['scalable', 'grid', 'service', 'discovery', 'uddi', 'authors', 'alphabetical', 'order', 'sujata', 'banerjee$', 'sujoy', 'basu$', 'shishir', 'garg', 'sukesh', 'garg', 'sung', 'ju', 'lee$', 'pramila', 'mullan', 'puneet', 'sharma$', 'hp', 'labs', 'page', 'mill', 'road', 'palo', 'alto', 'usa', 'sujata.banerjee,sujoy.basu,sungju.lee,puneet.sharma}@hp.com', 'france', 'telecom', 'r&d', 'division', 'gateway', 'blvd', 'south', 'san', 'francisco', 'usa', '-875', 'abstract', 'efficient', 'discovery', 'grid', 'services', 'essential', 'success', 'grid', 'computing', 'standardization', 'grids', 'web', 'services', 'need', 'scalable', 'web', 'service', 'discovery', 'mechanisms', 'grids', 'uddi', 'industry', 'standard', 'web', 'services', 'discovery', 'requirements', 'tight', 'replication', 'registries', 'lack', 'autonomous', 'control', 'widespread', 'deployment', 'usage', 'advent', 'grid', 'scalability', 'issue', 'uddi', 'roadblock', 'deployment', 'grids', 'paper', 'web', 'service', 'discovery', 'architecture', 'dude', 'uddi', 'deployment', 'engine', 'dude', 'dht', 'hash', 'tables', 'rendezvous', 'mechanism', 'multiple', 'uddi', 'registries', 'dude', 'consumers', 'multiple', 'registries', 'time', 'organizations', 'autonomous', 'control', 'registries', 'preliminary', 'prototype', 'planetlab', 'architecture', 'effective', 'distribution', 'uddi', 'registries', 'uddi', 'robust', 'scaling', 'issues', 'dude', 'architecture', 'scalable', 'distribution', 'uddi', 'grid', 'service', 'discovery', 'mechanism', 'categories', 'subject', 'descriptors', 'c2.4', 'systems', 'general', 'terms', 'design', 'experimentation', 'standardization', 'introduction', 'efficient', 'discovery', 'grid', 'services', 'essential', 'success', 'grid', 'computing', 'standardization', 'grids', 'web', 'services', 'need', 'scalable', 'web', 'service', 'permission', 'digital', 'hard', 'copies', 'work', 'personal', 'classroom', 'use', 'fee', 'copies', 'profit', 'commercial', 'advantage', 'copies', 'notice', 'citation', 'page', 'servers', 'lists', 'specific', 'permission', 'fee', 'mgc', 'november', '28-', 'december', 'grenoble', 'france', 'discovery', 'mechanisms', 'grids', 'grid', 'discovery', 'services', 'ability', 'resources', 'services', 'grids', 'ability', 'resource', 'service', 'information', 'addition', 'threshold', 'traps', 'specific', 'change', 'conditions', 'state', 'data', 'soft', 'state', 'recent', 'information', 'available', 'information', 'needs', 'variety', 'systems', 'purpose', 'grid', 'summary', 'information', 'fundamental', 'problem', 'need', 'scalable', 'huge', 'amounts', 'data', 'multiple', 'sources', 'web', 'services', 'community', 'need', 'service', 'discovery', 'grids', 'industry', 'standard', 'uddi', 'uddi', 'industry', 'standard', 'web', 'services', 'discovery', 'requirements', 'tight', 'replication', 'registries', 'lack', 'autonomous', 'control', 'things', 'widespread', 'deployment', 'usage', 'advent', 'grid', 'scalability', 'issue', 'uddi', 'roadblock', 'deployment', 'grids', 'paper', 'scalability', 'issue', 'way', 'services', 'multiple', 'registries', 'uddi', 'web', 'services', 'discovery', 'architecture', 'uddi', 'functionality', 'multiple', 'ways', 'different', 'computing', 'infrastructure', 'platforms', 'corba', 'dce', 'paper', 'hash', 'table', 'dht', 'technology', 'scalable', 'web', 'services', 'discovery', 'architecture', 'dht', 'peer', 'peer', 'p2p', 'system', 'structured', 'overlay', 'efficient', 'routing', 'network', 'crucial', 'design', 'choice', 'factors', 'motivating', 'factor', 'inherent', 'simplicity', 'abstraction', 'dhts', 'easy', 'applications', 'dhts', 'abstraction', 'applications', 'objective', 'hand', 'clear', 'computing', 'platforms', 'middleware', 'functionality', 'higher', 'overhead', 'complexity', 'second', 'motivating', 'factor', 'fact', 'dhts', 'new', 'tool', 'building', 'applicat']
# C-14.key
# C-14.txt
# ['sensor', 'deployment', 'strategy', 'target', 'detection', 'thomas', 'clouqueur', 'veradej', 'phipatanasuphorn', 'parameswaran', 'ramanathan', 'kewal', 'k.', 'saluja', 'university', 'wisconsin', 'madison', 'engineering', 'drive', 'madison', 'wi', 'clouqueu@ece.wisc.edu', 'abstract', 'order', 'region', 'traffic', 'traversal', 'sensors', 'collaborative', 'target', 'detection', 'sensor', 'network', 'certain', 'level', 'detection', 'performance', 'cost', 'deployment', 'paper', 'addresses', 'problem', 'path', 'exposure', 'measure', 'goodness', 'deployment', 'approach', 'sequential', 'deployment', 'steps', 'cost', 'deployment', 'detection', 'performance', 'number', 'sensors', 'step', 'categories', 'subject', 'descriptors', 'computer', 'communication', 'networks', 'systems', 'applications', 'c.3', 'special', 'purpose', 'application', 'systems', 'signal', 'processing', 'systems', 'general', 'terms', 'algorithms', 'design', 'performance', 'introduction', 'recent', 'advances', 'hardware', 'software', 'responsible', 'emergence', 'sensor', 'networks', 'capable', 'environment', 'data', 'decisions', 'observations', 'network', 'environment', 'specific', 'events', 'targets', 'specific', 'region', 'examples', 'systems', 'surveillance', 'monitoring', 'pollution', 'traffic', 'agriculture', 'civil', 'infrastructures', 'deployment', 'sensor', 'networks', 'application', 'environment', 'control', 'case', 'sensors', 'hand', 'deployment', 'undetermined', 'environment', 'unknown', 'hostile', 'case', 'sensors', 'aircraft', 'means', 'random', 'placement', 'paper', 'deployment', 'strategies', 'sensor', 'networks', 'target', 'detection', 'region', 'interest', 'order', 'target', 'region', 'sensors', 'local', 'observations', 'environment', 'global', 'decision', 'status', 'region', 'collaboration', 'local', 'processing', 'observations', 'communication', 'different', 'nodes', 'information', 'fusion', 'local', 'observations', 'sensors', 'position', 'performance', 'detection', 'algorithm', 'function', 'deployment', 'possible', 'measure', 'goodness', 'deployment', 'target', 'detection', 'path', 'exposure', 'measure', 'likelihood', 'target', 'region', 'path', 'higher', 'path', 'exposure', 'better', 'deployment', 'set', 'paths', 'environment', 'example', 'target', 'road', 'paths', 'roads', 'study', 'deployment', 'random', 'practical', 'applications', 'region', 'accessible', 'precise', 'placement', 'sensors', 'focus', 'paper', 'number', 'sensors', 'target', 'detection', 'region', 'interest', 'tradeoffs', 'network', 'performance', 'cost', 'sensors', 'cost', 'sensors', 'paper', 'section', 'definition', 'path', 'exposure', 'method', 'exposure', 'path', 'section', 'problem', 'random', 'deployment', 'solutions', 'analytical', 'study', 'solutions', 'section', 'section', 'simulation', 'results', 'section', 'optimum', 'solution', 'environment', 'paper', 'section', 'path', 'exposure', 'section', 'model', 'sensor', 'network', 'target', 'detection', 'definition', 'path', 'exposure', 'expressions', 'path', 'exposure', 'model', 'rectangular', 'sensor', 'field', 'n', 'sensors', 'de42', 'ployed', 'locations', 'si', 'n.', 'target', 'location', 'u', 'signal', 'sensors', 'signal', 'target', 'polynomial', 'distance', 'decay', 'coefficient', 'k', 'signal', 'energy', 'target', 'location', 'u', 'sensor', 'si', 'k', '||u', '−', 'si||k', 'k', 'energy', 'target', '||u', '−', 'si||', 'geometric', 'distance', 'target', 'sensor', 'environment', 'value', 'k', 'energy', 'measurements', 'sensor', 'noise', 'ni', 'noise', 'energy', 'sensor', 'particular', 'measurement', 'total', 'energy', 'sensor', 'target', 'location', 'u', 'ni', 'k', '||u', '−', 'si||k', 'ni', 'sensors', 'consensus', 'decision']
# C-17.key
# C-17.txt
# ['deployment', 'issues', 'voip', 'conferencing', 'system', 'virtual', 'conferencing', 'environment', 'r.', 'venkatesha', 'prasad', 'richard', 'hurni', 'ii', 'h.s', 'jamadagni', 'iii', 'h.n', 'shankar', 'iv', 'centre', 'electronics', 'design', 'technology', 'indian', 'institute', 'science', 'bangalore', 'india', 'telephone', 'vprasad', 'hsjam}@cedt.iisc.ernet.in', 'abstract', 'real', 'time', 'services', 'large', 'circuitswitched', 'networks', 'recent', 'trends', 'services', 'packet', 'networks', 'audio', 'conferencing', 'issues', 'scalability', 'quality', 'conference', 'application', 'floor', 'control', 'load', 'clients', 'servers', 'paper', 'audio', 'service', 'framework', 'virtual', 'conferencing', 'environment', 'vce', 'system', 'large', 'number', 'end', 'users', 'time', 'internet', 'framework', 'conference', 'servers', 'audio', 'handling', 'sip', 'capabilities', 'signaling', 'purposes', 'client', 'selection', 'recent', 'quantifier', 'loudness', 'number', 'physical', 'face', 'face', 'conference', 'deployment', 'issues', 'solution', 'terms', 'scalability', 'interactivity', 'techniques', 'traffic', 'conference', 'server', 'cs', 'application', 'campus', 'wide', 'network', 'institute', 'categories', 'subjects', 'descriptors', 'computer', 'communication', 'networks', 'systems', 'client', 'server', 'applications', 'general', 'terms', 'algorithms', 'performance', 'design', 'theory', 'introduction', 'today', 'internet', 'ip', 'protocol', 'suite', 'transport', 'data', 'best', 'effort', 'data', 'delivery', 'delay', 'constraints', 'characteristics', 'separate', 'traditional', 'data', 'hand', 'voice', 'video', 'applications', 'time', 'sensitive', 'voice', 'video', 'applications', 'internet', 'inadequacy', 'internet', 'telephone', 'services', 'internet', 'virtual', 'conference', 'teleconference', 'facility', 'cutting', 'edge', 'audio', 'video', 'conferencing', 'internet', 'popular', 'advantages', 'bandwidth', 'teleconference', 'internet', 'number', 'participants', 'bandwidth', 'audio', 'quality', 'challenge', 'internet', 'telephony', 'additional', 'critical', 'issues', 'packet', 'delay', 'echo', 'audio', 'clients', 'd', 'automatic', 'selection', 'clients', 'conference', 'e', 'playout', 'mixed', 'audio', 'client', 'clients', 'capable', 'audio', 'streams', 'clients', 'dumb', 'clients', 'g', 'number', 'active', 'clients', 'conference', 'voice', 'quality', 'requirements', 'technology', 'point', 'view', 'user', 'perspective', 'interactions', 'essential', 'factors', 'plenty', 'discussion', 'hci', 'cscw', 'community', 'use', 'ethnomethodology', 'design', 'cscw', 'applications', 'basic', 'approach', 'larger', 'bandwidth', 'facilities', 'advanced', 'control', 'mechanisms', 'better', 'quality', 'interaction', 'approach', 'functional', 'utility', 'environment', 'collaboration', 'eckehard', 'doerry', 'approach', 'form', 'function', 'need', 'approach', 'aspects', 'technical', 'functional', 'functional', 'aspect', 'detail', 'work', 'video', 'conferencing', 'inclusion', 'conference', 'quality', 'focus', 'virtual', 'audio', 'environments', 'challenges', 'virtual', 'audio', 'conferences', 'motivations', 'relevant', 'literature', 'section', 'architecture', 'system', 'section', 'description', 'algorithms', 'setup', 'deployment', 'issues', 'discussion', 'swiss', 'federal', 'institute', 'technology', 'lausanne', 'visitor', 'cedt', 'pesit', 'nias', 'bangalore', 'india.iv', 'performance', 'implementation', 'issues', 'challenges', 'voip', 'conferencing', 'challenges', 'voip', 'application', 'particular', 'concern', 'process', 'ease', 'use', 'conferencing', 'simple', 'users', 'domain', 'expertise', 'management', 'addition', 'removal', 'clients', 'servers', 'uncomplicated', 'application', 'development', 'specific', 'characteristics', 'system', 'network', 'layers', 'ease', 'use', 'available', 'feasible', 'viable', 'technologies', 'scalability', 'conferencing', 'uninterrupted', 'heavy', 'loads', 'additional', 'users']
# C-18.key
# C-18.txt
# ['initial', 'analysis', 'presentation', 'malware', 'swarm', 'like', 'behavior', 'fernando', 'c.col´on', 'osorio', 'wireless', 'system', 'security', 'research', 'laboratory', 'w.s.s.r.l', 'lakeside', 'avneue', 'marlboro', 'massachusetts', 'fcco@cs.wpi.edu', 'zachi', 'klopman', 'wireless', 'system', 'security', 'research', 'laboratory', 'w.s.s.r.l', 'lakeside', 'avneue', 'marlboro', 'massachusetts', 'abstract', 'slammer', 'fastest', 'computer', 'worm', 'history', 'percent', 'vulnerable', 'internets', 'hosts', 'minutes', 'main', 'action', 'slammer', 'worm', 'unsophisticated', 'replication', 'human', 'response', 'ineffective', 'countermeasures', 'strategies', 'rate', 'detection', 'algorithms', 'strategies', 'worms', 'behaviors', 'similar', 'slammer', 'work', 'hypothesis', 'generation', 'worms', 'different', 'techniques', 'ineffective', 'new', 'generation', 'worms', 'swarm', 'worms', 'behavior', 'concept', 'emergent', 'intelligence', 'emergent', 'intelligence', 'behavior', 'systems', 'biological', 'systems', 'ants', 'bees', 'simple', 'local', 'interactions', 'autonomous', 'members', 'simple', 'primitive', 'actions', 'rise', 'complex', 'intelligent', 'global', 'behavior', 'manuscript', 'basic', 'principles', 'idea', 'swarm', 'worms', 'basic', 'structure', 'order', 'swarm', 'worm', 'addition', 'preliminary', 'results', 'propagation', 'speeds', 'swarm', 'worm', 'zachik', 'worm', 'zachik', 'capable', 'rate', 'orders', 'magnitude', 'similar', 'worms', 'swarm', 'capabilities', 'categories', 'subject', 'descriptors', 'systems', 'intrusion', 'detection', 'security', 'protection', 'invasive', 'software', 'general', 'terms', 'experimentation', 'security', 'introduction', 'previouswork', 'early', 'morning', 'hours', 'gmt', 'january', 'fastest', 'computer', 'worm', 'history', 'internet', 'minutes', 'infected', 'host', 'patient', 'percent', 'vulnerable', 'hosts', 'significant', 'disruption', 'global', 'internet', 'infrastructure', 'vern', 'paxson', 'international', 'computer', 'science', 'institute', 'lawrence', 'berkeley', 'national', 'laboratory', 'analysis', 'slammer', 'slammer', 'worm', 'human', 'response', 'ineffective', 'interesting', 'perspective', 'spread', 'slammer', 'unsophisticated', 'worm', 'benign', 'behavior', 'self', 'reproduction', 'slammer', 'researchers', 'behaviors', 'fast', 'worms', 'countermeasures', 'strategies', 'rate', 'detection', 'algorithms', 'example', 'zou', 'et', 'al', 'scheme', 'kalman', 'filter', 'early', 'propagation', 'worm', 'researchers', 'use', 'detectors', 'rates', 'destination', 'unreachable', 'messages', 'firewalls', 'significant', 'increase', 'normal', 'organization', 'potential', 'presence', 'worm', 'strategies', 'fighting', 'war', 'syndrome', 'systems', 'worms', 'behaviors', 'similar', 'slammer', 'work', 'hypothesis', 'generation', 'worms', 'different', 'techniques', 'significant', 'limitations', 'new', 'generation', 'worms', 'swarm', 'worms', 'behavior', 'concept', 'emergent', 'intelligence', 'concept', 'emergent', 'intelligence', 'association', 'biological', 'systems', 'studies', 'early', 'researchers', 'variety', 'interesting', 'insect', 'animal', 'behaviors', 'wild', 'flock', 'birds', 'sky', 'group', 'ants', 'forages', 'food', 'school', 'fish', 'swims', 'predator', 'ands', 'general', 'kind', 'aggregate', 'motion', 'swarm', 'behavior', 'biologists', 'computer', 'scientists', 'field', 'artificial', 'intelligence', 'biological', 'swarms', 'models', 'elements', 'swarm', 'goals', 'recent', 'years', 'study', 'swarm', 'intelligence', 'important', 'fields', 'robotics', 'design', 'mobile', 'ad', 'networks', 'manets', 'design', 'intrusion', 'detection', 'systems', 'study', 'traffic', 'patterns', 'transportation', 'systems', 'military', 'applications', 'areas', 'basic', 'concepts', 'decade', 'swarms', 'swarm', 'behavior', 'basic', 'components', 'simplicity', 'logic', 'actions', 'swarm']
# C-19.key
# C-19.txt
# ['service', 'interface', 'new', 'abstraction', 'protocols∗', 'olivier', 'r¨utti', 'paweł', 't.', 'wojciechowski', 'andr´e', 'schiper', 'ecole', 'polytechnique', 'f´ed´erale', 'de', 'lausanne', 'epfl', 'lausanne', 'switzerland', 'olivier.rutti', 'pawel.wojciechowski', 'andre.schiper}@epfl.ch', 'abstract', 'paper', 'approaches', 'design', 'protocol', 'frameworks', 'tools', 'modular', 'network', 'protocols', 'common', 'approach', 'events', 'main', 'abstraction', 'local', 'interaction', 'protocol', 'modules', 'alternative', 'approach', 'service', 'abstraction', 'suitable', 'modular', 'protocols', 'advanced', 'features', 'design', 'protocols', 'dynamic', 'update', 'protocols', 'experimental', 'implementation', 'service', 'protocol', 'framework', 'java', 'categories', 'subject', 'descriptors', 'computer', 'communication', 'networks', 'applications', 'introduction', 'protocol', 'frameworks', 'cactus', 'appia', 'ensemble', 'eva', 'sdl', 'neko[6', 'programming', 'tools', 'modular', 'network', 'protocols', 'complex', 'protocols', 'modules', 'approach', 'code', 'reuse', 'customization', 'protocols', 'order', 'needs', 'different', 'applications', 'protocol', 'modules', 'system', 'features', 'protocol', 'frameworks', 'interesting', 'technology', 'adaptable', 'systems', 'important', 'class', 'applications', 'protocol', 'frameworks', 'events', 'frameworks', 'abstraction', 'events', 'asynchronous', 'communication', 'different', 'modules', 'machine', 'use', 'events', 'problems', 'instance', 'composition', 'modules', 'connectors', 'route', 'events', 'burden', 'protocol', 'composer', 'protocol', 'frameworks', 'appia', 'eva', 'event', 'approach', 'channels', 'opinion', 'solution', 'satisfactory', 'composition', 'complex', 'protocol', 'stacks', 'difficult', 'paper', 'new', 'approach', 'modular', 'protocols', 'service', 'abstraction', 'new', 'approach', 'common', 'event', 'approach', 'protocol', 'frameworks', 'services', 'advantages', 'straightforward', 'protocol', 'composition', 'clear', 'implementation', 'better', 'support', 'dynamic', 'replacement', 'protocols', 'claims', 'samoa', 'experimental', 'protocol', 'framework', 'service', 'approach', 'composition', 'implementation', 'framework', 'service-', 'event', 'implementations', 'adaptive', 'group', 'communication', 'middleware', 'paper', 'follows', 'section', 'general', 'notions', 'section', 'main', 'characteristics', 'event', 'frameworks', 'distinct', 'framework', 'section', 'new', 'approach', 'service', 'abstraction', 'section', 'advantages', 'service', 'protocol', 'framework', 'event', 'protocol', 'framework', 'description', 'experimental', 'implementation', 'section', 'section', 'protocol', 'frameworks', 'section', 'notions', 'common', 'protocol', 'frameworks', 'protocols', 'protocol', 'modules', 'protocol', 'algorithm', 'specific', 'problem', 'system', 'tcp', 'protocol', 'reliable', 'channel', 'problem', 'protocol', 'set', 'identical', 'protocol', 'modules', 'different', 'machines', 'protocol', 'stacks', 'stack', 'set', 'protocol', 'modules', 'different', 'protocols', 'machine', 'stack', 'protocol', 'module', 'protocol', 'modules', 'stack', 'protocol', 'modules', 'remainder', 'paper', 'terms', 'machine', 'stack', 's1', 'q1', 'r1', 'p1', 'network', 'figure', 'example', 'protocol', 'stack', 'figure', 'example', 'protocol', 'stack', 'protocol', 'modules', 'capital', 'letters', 'natural', 'number', 'p1', 'q1', 'r1', 's1', 'pi', 'protocol', 'module', 'protocol', 'p', 'stack', 'notation', 'paper', 'modules', 'white', 'boxes', 'arrows', 'module', 'interactions', 'instance', 'protocol', 'module', 'p1', 'protocol', 'module', 'q1', 'fig', 'protocol', 'module', 'interactions', 'different', 'kinds', 'interaction', 'protocol', 'modules', 'requests', 'protocol', 'modules', 'request', 'protocol', 'module', 'pi', 'asynchronous', 'pi', 'protocol', 'module', 'replies', 'results', 'request', 'single', 'request', 'replies', 'protocol']
# C-20.key
# C-20.txt
# ['live', 'data', 'center', 'migration', 'wans', 'robust', 'cooperative', 'context', 'aware', 'approach', 'k.k', 'ramakrishnan', 'prashant', 'shenoy', 'jacobus', 'van', 'der', 'merwe', 'at&t', 'labs', 'research', 'university', 'massachusetts', 'abstract', 'significant', 'concern', 'internet', 'service', 'providers', 'operation', 'availability', 'services', 'face', 'outages', 'unplanned', 'paper', 'cooperative', 'context', 'aware', 'approach', 'data', 'center', 'migration', 'wans', 'outages', 'non', 'disruptive', 'manner', 'high', 'availability', 'data', 'center', 'services', 'face', 'unanticipated', 'outages', 'data', 'center', 'facilities', 'use', 'server', 'virtualization', 'technologies', 'replication', 'migration', 'server', 'functions', 'new', 'network', 'functions', 'server', 'migration', 'replication', 'wide', 'area', 'networks', 'internet', 'utility', 'intelligent', 'dynamic', 'storage', 'replication', 'technology', 'applications', 'access', 'data', 'face', 'outages', 'tight', 'recovery', 'point', 'objectives', 'categories', 'subject', 'descriptors', 'computer', 'communication', 'networks', 'systems', 'general', 'terms', 'design', 'reliability', 'introduction', 'significant', 'concern', 'internet', 'service', 'providers', 'operation', 'availability', 'services', 'face', 'outages', 'unplanned', 'concerns', 'use', 'internet', 'mission', 'critical', 'business', 'real', 'time', 'entertainment', 'applications', 'minor', 'outage', 'large', 'number', 'users', 'today', 'services', 'data', 'centers', 'recent', 'advances', 'server', 'virtualization', 'technologies', 'live', 'migration', 'services', 'local', 'area', 'network', 'lan', 'environment', 'lan', 'environment', 'technologies', 'effective', 'tool', 'data', 'center', 'management', 'non', 'disruptive', 'fashion', 'maintenance', 'events', 'dynamic', 'fashion', 'load', 'physical', 'servers', 'data', 'center', 'technologies', 'lan', 'environment', 'services', 'virtual', 'server', 'migration', 'services', 'virtualization', 'framework', 'virtual', 'server', 'physical', 'server', 'significant', 'downtime', 'service', 'application', 'particular', 'virtual', 'server', 'network', 'address', 'ongoing', 'network', 'level', 'interactions', 'lan', 'environment', 'storage', 'requirements', 'network', 'storage', 'nas', 'storage', 'area', 'network', 'san', 'reachable', 'new', 'physical', 'server', 'location', 'storage', 'access', 'wide', 'area', 'environment', 'wan', 'live', 'server', 'migration', 'achievable', 'reasons', 'migration', 'virtual', 'server', 'network', 'address', 'network', 'connectivity', 'viewpoint', 'server', 'indistinguishable', 'original', 'lan', 'environment', 'current', 'mechanisms', 'available', 'feat', 'wan', 'environment', 'sophisticated', 'remote', 'replication', 'mechanisms', 'context', 'disaster', 'recovery', 'mechanisms', 'suited', 'data', 'center', 'migration', 'general', 'available', 'technologies', 'unaware', 'application', 'service', 'level', 'semantics', 'paper', 'design', 'live', 'service', 'migration', 'wans', 'design', 'use', 'server', 'virtualization', 'technologies', 'network', 'storage', 'mechanisms', 'migration', 'wan', 'essence', 'approach', 'cooperative', 'context', 'aware', 'migration', 'migration', 'management', 'system', 'data', 'center', 'migration', 'subsystems', 'server', 'platforms', 'wide', 'area', 'network', 'disk', 'storage', 'system', 'similar', 'nature', 'lan', 'work', 'migration', 'technologies', 'wide', 'area', 'network', 'unique', 'challenges', 'knowledge', 'main', 'contribution', 'design', 'framework', 'migration', 'wan', 'subsystems', 'data', 'center', 'services', 'new', 'mechanisms', 'extensions', 'technologies', 'cooperative', 'context', 'aware', 'functionality', 'different', 'subsystems', 'live', 'data', 'center', 'migration', 'wans', 'essential', 'subsystems', 'services', 'data', 'center', 'servers', 'application', 'service', 'logic', 'services', 'data', 'center', 'access', 'network', 'internet', 'virtual', 'private', 'networks' ...
# C-22.key
# C-22.txt
# ['runtime', 'metrics', 'collection', 'middleware', 'adaptation', 'mobile', 'applications', 'hendrik', 'gani', 'school', 'computer', 'science', 'information', 'technology', 'rmit', 'university', 'melbourne', 'australia', 'hgani@cs.rmit.edu.au', 'caspar', 'ryan', 'school', 'computer', 'science', 'information', 'technology', 'rmit', 'university', 'melbourne', 'australia', 'caspar@cs.rmit.edu.au', 'pablo', 'rossi', 'school', 'computer', 'science', 'information', 'technology', 'rmit', 'university', 'melbourne', 'australia', 'abstract', 'paper', 'terms', 'worst', 'case', 'performance', 'online', 'metrics', 'collection', 'strategy', 'application', 'adaptation', 'object', 'mobility', 'mobile', 'object', 'framework', 'middleware', 'solution', 'abstract', 'representation', 'mobile', 'object', 'system', 'containers', 'metrics', 'specific', 'component', 'host', 'managers', 'runtimes', 'mobile', 'objects', 'key', 'feature', 'solution', 'specification', 'multiple', 'configurable', 'criteria', 'measurement', 'propagation', 'metrics', 'system', 'mobjex', 'platform', 'basis', 'implementation', 'testing', 'number', 'laboratory', 'tests', 'scalability', 'efficiency', 'application', 'simple', 'measurement', 'propagation', 'criteria', 'collection', 'overhead', 'categories', 'subject', 'descriptors', 'systems', 'metrics', 'general', 'terms', 'measurement', 'performance', 'introduction', 'different', 'capabilities', 'mobile', 'devices', 'varying', 'speed', 'error', 'rate', 'disconnection', 'characteristics', 'mobile', 'networks', 'difficult', 'advance', 'exact', 'execution', 'environment', 'mobile', 'applications', 'solution', 'attention', 'research', 'community', 'application', 'adaptation', 'applications', 'behaviour', 'response', 'factors', 'network', 'processor', 'memory', 'usage', 'effective', 'adaptation', 'detailed', 'date', 'information', 'system', 'software', 'metrics', 'system', 'wide', 'information', 'processor', 'memory', 'network', 'load', 'environmental', 'metrics', 'metrics', 'application', 'behaviour', 'software', 'metrics', 'type', 'metrics', 'adaptation', 'dependent', 'type', 'adaptation', 'example', 'service', 'adaptation', 'service', 'quality', 'service', 'behaviour', 'response', 'changes', 'runtime', 'environment', 'detailed', 'environmental', 'metrics', 'simple', 'software', 'metrics', 'hand', 'adaptation', 'object', 'mobility', 'detailed', 'software', 'metrics', 'object', 'placement', 'dependent', 'execution', 'characteristics', 'mobile', 'objects', 'exception', 'mobjex', 'mobile', 'object', 'systems', 'voyager', 'fargo', 'javaparty', 'adaptation', 'metrics', 'collection', 'process', 'process', 'case', 'mobjex', 'adaptation', 'engine', 'preliminary', 'testing', 'synthetic', 'pre', 'scripted', 'metrics', 'little', 'prior', 'work', 'dynamic', 'collection', 'software', 'metrics', 'mobile', 'object', 'frameworks', 'means', 'main', 'contribution', 'paper', 'solution', 'dynamic', 'metrics', 'collection', 'adaptation', 'object', 'mobility', 'mobile', 'applications', 'problem', 'non', 'trivial', 'typical', 'mobile', 'object', 'frameworks', 'multiple', 'application', 'middleware', 'components', 'metrics', 'collection', 'different', 'locations', 'results', 'adaptation', 'engine', 'cases', 'location', 'metric', 'places', 'decision', 'efficiency', 'solution', 'section', 'rest', 'paper', 'section', 'general', 'structure', 'implementation', 'mobile', 'object', 'frameworks', 'order', 'challenges', 'collection', 'propagation', 'delivery', 'metrics', 'section', 'section', 'initial', 'testing', 'results', 'section', 'summary', 'conclusions', 'discussion', 'future', 'work', 'background', 'general', 'object', 'application', 'objects', 'functionality', 'problem', 'domain', 'mobile', 'object', 'frameworks', 'objects', 'mobile', 'objects', 'middleware', 'support', 'objects', 'runtime', 'hosts', 'minimum', 'mobile', 'object', 'framework', 'mobile', 'application', 'following', 'components', 'runtimes', 'mobile', 'objects', 'proxies', 'terminology', 'i ...
# C-23.key
# C-23.txt
# ['implementation', 'dynamic', 'adjustment', 'mechanism', 'efficient', 'replica', 'selection', 'data', 'grid', 'environments', 'chao', 'tung', 'yang', 'hsien', 'yang', 'chun', 'hsiang', 'chen', 'shih', 'yu', 'wang', 'high', 'performance', 'computing', 'laboratory', 'department', 'computer', 'science', 'information', 'engineering', 'tunghai', 'university', 'taichung', 'city', 'taiwan', 'r.o.c', 'g932813@thu.edu.tw', 'abstract', 'co', 'allocation', 'architecture', 'order', 'parallel', 'downloading', 'datasets', 'multiple', 'servers', 'co', 'allocation', 'strategies', 'rate', 'differences', 'client', 'server', 'links', 'dynamic', 'rate', 'fluctuations', 'files', 'multiple', 'blocks', 'equal', 'sizes', 'major', 'obstacle', 'idle', 'time', 'faster', 'servers', 'slowest', 'server', 'final', 'block', 'important', 'differences', 'time', 'replica', 'servers', 'paper', 'dynamic', 'coallocation', 'scheme', 'recursive', 'adjustment', 'co', 'allocation', 'scheme', 'performance', 'data', 'transfer', 'data', 'grids', 'approach', 'idle', 'time', 'slowest', 'server', 'data', 'transfer', 'completion', 'time', 'effective', 'scheme', 'cost', 'data', 'blocks', 'categories', 'subject', 'descriptors', 'systems', 'applications', 'online', 'information', 'services', 'data', 'sharing', 'web', 'services', 'general', 'terms', 'management', 'performance', 'design', 'experimentation', 'introduction', 'data', 'grids', 'resources', 'large', 'size', 'dataset', 'management', 'problems', 'data', 'grid', 'applications', 'large', 'numbers', 'data', 'files', 'grid', 'environment', 'certain', 'data', 'intensive', 'scientific', 'applications', 'high', 'energy', 'physics', 'bioinformatics', 'applications', 'virtual', 'astrophysical', 'observatories', 'huge', 'amounts', 'data', 'data', 'file', 'management', 'systems', 'files', 'data', 'transfers', 'data', 'access', 'data', 'grid', 'infrastructure', 'data', 'storage', 'devices', 'data', 'management', 'services', 'grid', 'environment', 'consists', 'scattered', 'computing', 'storage', 'resources', 'different', 'countries', 'regions', 'accessible', 'users', 'popular', 'content', 'servers', 'practice', 'large', 'scale', 'data', 'scientific', 'communities', 'technology', 'large', 'datasets', 'sites', 'large', 'datasets', 'replica', 'locations', 'varied', 'performance', 'rates', 'replica', 'sites', 'different', 'architectures', 'system', 'loadings', 'network', 'connectivity', 'bandwidth', 'quality', 'important', 'factor', 'transfers', 'clients', 'servers', 'download', 'speeds', 'bandwidth', 'traffic', 'congestion', 'links', 'servers', 'clients', 'way', 'download', 'speeds', 'best', 'replica', 'locations', 'replica', 'selection', 'techniques', 'method', 'best', 'servers', 'optimum', 'transfer', 'rates', 'bandwidth', 'quality', 'nature', 'internet', 'way', 'co', 'allocation', 'technology', 'data', 'co', 'allocation', 'data', 'transfers', 'clients', 'data', 'multiple', 'locations', 'multiple', 'connections', 'parallel', 'performance', 'single', 'server', 'cases', 'internet', 'congestion', 'problem', 'co', 'allocation', 'strategies', 'previous', 'work', 'idle', 'time', 'drawback', 'faster', 'servers', 'slowest', 'server', 'final', 'block', 'important', 'differences', 'time', 'replica', 'servers', 'paper', 'dynamic', 'co', 'allocation', 'scheme', 'co', 'allocation', 'grid', 'data', 'transfer', 'architecture', 'recursiveadjustment', 'co', 'allocation', 'scheme', 'idle', 'time', 'slowest', 'server', 'data', 'transfer', 'performance', 'experimental', 'results', 'approach', 'superior', 'previous', 'methods', 'best', 'overall', 'performance', 'combination', 'cost', 'effective', 'scheme', 'remainder', 'paper', 'background', 'review', 'studies', 'section', 'co', 'allocation', 'architecture', 'related', 'work', 'section', 'section', 'efficient', 'replica', 'selection', 'service', 'research', 'approaches', 'section', 'experimental', 'results', 'performance', 'evaluation', 'scheme', 'section', 'section', 'research', 'paper', 'background', ' ...
# C-27.key
# C-27.txt
# ['high', 'accuracy', 'low', 'cost', 'localization', 'system', 'wireless', 'sensor', 'networks', 'radu', 'stoleru', 'tian', 'john', 'a.', 'stankovic', 'david', 'luebke', 'department', 'computer', 'science', 'university', 'virginia', 'charlottesville', 'va', 'stoleru', 'tianhe', 'stankovic', 'luebke}@cs.virginia.edu', 'abstract', 'problem', 'localization', 'wireless', 'sensor', 'nodes', 'difficult', 'realities', 'real', 'world', 'environments', 'paper', 'design', 'novel', 'localization', 'system', 'spotlight', 'system', 'spatio', 'temporal', 'properties', 'events', 'network', 'light', 'locations', 'sensor', 'nodes', 'high', 'accuracy', 'localization', 'aid', 'expensive', 'hardware', 'sensor', 'nodes', 'localization', 'systems', 'performance', 'system', 'deployments', 'mica2', 'xsm', 'motes', 'performance', 'evaluations', 'real', 'system', 'cm', 'localization', 'error', 'sensor', 'network', 'number', 'nodes', 'area', 'minutes', 'device', 'costs', 'best', 'knowledge', 'report', 'sub', 'meter', 'localization', 'error', 'outdoor', 'environment', 'wireless', 'sensor', 'nodes', 'hardware', 'categories', 'subject', 'descriptors', 'computer', 'communications', 'networks', 'systems', 'c.3', 'special', 'purpose', 'application', 'systems', 'real', 'time', 'systems', 'general', 'terms', 'algorithms', 'measurement', 'performance', 'design', 'experimentation', 'introduction', 'wireless', 'sensor', 'network', 'systems', 'promising', 'applications', 'military', 'surveillance', 'habitat', 'monitoring', 'wildlife', 'tracking', 'etc', 'middleware', 'services', 'applications', 'localization', 'finding', 'position', 'sensor', 'nodes', 'difficult', 'research', 'challenges', 'applications', 'networked', 'sensor', 'nodes', 'location', 'awareness', 'operations', 'data', 'location', 'context', 'indispensable', 'requirement', 'sensor', 'node', 'able', 'location', 'approaches', 'literature', 'clear', 'solutions', 'board', 'gps', 'typical', 'high', 'end', 'solution', 'sophisticated', 'hardware', 'high', 'resolution', 'time', 'synchronization', 'satellites', 'constraints', 'power', 'cost', 'tiny', 'sensor', 'nodes', 'viable', 'solution', 'solutions', 'node', 'devices', 'neighboring', 'nodes', 'difficulties', 'approaches', 'twofold', 'constraints', 'form', 'factor', 'power', 'supply', 'effective', 'ranges', 'devices', 'limited', 'example', 'effective', 'range', 'ultrasonic', 'transducers', 'cricket', 'system', 'meters', 'sender', 'receiver', 'sensor', 'nodes', 'static', 'location', 'cost', 'effective', 'sensors', 'special', 'circuitry', 'time', 'localization', 'limitations', 'range', 'free', 'localization', 'schemes', 'schemes', 'location', 'sensor', 'nodes', 'radio', 'connectivity', 'information', 'neighboring', 'nodes', 'approaches', 'need', 'high', 'cost', 'specialized', 'hardware', 'cost', 'accurate', 'localization', 'addition', 'radio', 'propagation', 'characteristics', 'time', 'environment', 'dependent', 'high', 'calibration', 'costs', 'range', 'free', 'localizations', 'schemes', 'limitations', 'mind', 'paper', 'research', 'challenge', 'need', 'high', 'accuracy', 'location', 'estimation', 'cost', 'answer', 'challenge', 'localization', 'system', 'spotlight', 'system', 'asymmetric', 'architecture', 'sensor', 'nodes', 'additional', 'hardware', 'sophisticated', 'hardware', 'computation', 'single', 'spotlight', 'device', 'spotlight', 'device', 'steerable', 'laser', 'light', 'source', 'sensor', 'nodes', 'terrain', 'localization', 'accurate', 'tens', 'centimeters', 'range', 'localization', 'schemes', 'effective', 'range', 'thousands', 'meters', 'solutions', 'ultra', 'sound', 'acoustic', 'time', 'single', 'sophisticated', 'device', 'network', 'cost', 'smaller', 'cost', 'hardware', 'components', 'individual', 'sensors', 'work', 'section', 'prior', 'work', 'localization', 'major', 'categories']
# C-28.key
# C-28.txt
# ['packageblast', 'adaptive', 'multi', 'policy', 'grid', 'service', 'biological', 'sequence', 'comparison', '∗', 'marcelo', 's.', 'sousa', 'university', 'brasilia', 'campus', 'unb', 'icc', 'norte', 'sub', 'solo', 'brasilia', 'brazil', 'msousa@unb.br', 'alba', 'cristina', 'm.', 'a.', 'melo', 'university', 'brasilia', 'campus', 'unb', 'icc', 'norte', 'sub', 'solo', 'brasilia', 'brazil', 'alves@unb.br', 'abstract', 'paper', 'adaptive', 'task', 'allocation', 'framework', 'blast', 'searches', 'grid', 'environment', 'sequence', 'database', 'segments', 'framework', 'packageblast', 'infrastructure', 'task', 'allocation', 'strategies', 'mechanism', 'grid', 'nodes', 'execution', 'weight', 'allocation', 'policy', 'current', 'computational', 'power', 'nodes', 'results', 'good', 'speedups', 'single', 'allocation', 'strategy', 'able', 'lowest', 'execution', 'times', 'scenarios', 'categories', 'subject', 'descriptors', 'systems', 'applications', 'life', 'medical', 'sciences', 'biology', 'genetics', 'introduction', 'biological', 'sequence', 'comparison', 'sequence', 'alignment', 'important', 'problems', 'computational', 'biology', 'number', 'diversity', 'sequences', 'frequency', 'sw', 'exact', 'algorithm', 'best', 'local', 'alignment', 'sequences', 'size', 'quadratic', 'time', 'space', 'genome', 'projects', 'size', 'sequences', 'o(n2', 'solution', 'expensive', 'reason', 'heuristics', 'blast', 'execution', 'time', 'popularity', 'internet', 'possible', 'interconnection', 'millions', 'powerful', 'machines', 'global', 'scale', 'idea', 'grid', 'computing', 'cooperative', 'secure', 'sharing', 'non', 'dedicated', 'heterogeneous', 'resources', 'resource', 'scheduling', 'important', 'components', 'grid', 'system', 'choice', 'best', 'resources', 'particular', 'application', 'task', 'allocation', 'np', 'complete', 'problem', 'grid', 'applications', 'high', 'communication', 'rates', 'master', 'slave', 'model', 'order', 'master', 'slave', 'applications', 'task', 'allocation', 'policies', 'self', 'scheduling', 'fac2', 'choice', 'best', 'allocation', 'policy', 'application', 'access', 'pattern', 'environment', 'paper', 'adaptive', 'multi', 'policy', 'grid', 'service', 'blast', 'searches', 'grids', 'segmented', 'genetic', 'databases', 'packageblast', 'executes', 'globus', 'allocation', 'policies', 'adaptive', 'mechanism', 'weights', 'grid', 'nodes', 'account', 'current', 'workload', 'grid', 'service', 'multiple', 'task', 'policies', 'segmented', 'database', 'heterogeneous', 'non', 'dedicated', 'platform', 'paper', 'follows', 'section', 'sequence', 'comparison', 'problem', 'blast', 'algorithm', 'section', 'allocation', 'policies', 'grids', 'section', 'work', 'section', 'design', 'packageblast', 'experimental', 'results', 'section', 'section', 'paper', 'sequence', 'comparison', 'sequences', 'best', 'alignment', 'sequence', 'correspondence', 'similar', 'characters', 'alignment', 'sequences', 'score', 'figure', 'column', 'instance', 'characters', 'identical', 'characters', 'different', 'space', 'score', 'sum', 'values', 'maximal', 'score', 'similarity', 'sequences', 'exact', 'local', 'sequence', 'alignments', 'algorithm', 'sw', 'dynamic', 'programming', 'quadratic', 'time', 'space', 'complexity', 'biological', 'sequence', 'thousands', 'millions', 'sequences', 'genetic', 'data', 'banks', 'millions', 'entries', 'billions', 'nucleotides', 'genbank', 'important', 'public', 'gene', 'repositories', 'g', 'c', 'g', 'g', 't', 't', 'g', 'g', 't', 'c', 'g', 'g', 't', 'g', '−2', '−1', 'σ', 'figure', 'example', 'alignment', 'score', 'current', 'growth', 'rate', 'databases', 'terabytes', 'scenario', 'use', 'exact', 'methods', 'sw', 'prohibitive', 'reason', 'faster', 'heuristic', 'methods', 'best', 'alignment', 'heuristic', 'methods', 'concepts', 'sensitivity', 'sensibility', 'sensitivity', 'rate', 'method', 'similar', 'sequences', 'sensibility', 'rate', 'method', 'sequences', 'similar', 'blast', 'heuristic', 'method', 'sequence', 'comparison', 'blast', 'algorithm', 'blast', 'b ...
# C-29.key
# C-29.txt
# ['implementation', 'performance', 'evaluation', 'conflex', 'g', 'grid', 'molecular', 'conformational', 'space', 'search', 'program', 'omnirpc', 'yoshihiro', 'nakajima', 'graduate', 'school', 'systems', 'information', 'engineering', 'university', 'tsukuba', 'tsukuba', 'japan', 'yoshihiro@hpcs.is.tsukuba.ac.jp', 'mitsuhisa', 'sato', 'institute', 'information', 'sciences', 'electronics', 'university', 'tsukuba', 'tsukuba', 'japan', 'msato@is.tsukuba.ac.jp', 'hitoshi', 'goto', 'knowledge', 'information', 'engineering', 'toyohashi', 'university', 'technology', 'toyohashi', 'japan', 'gotoh@cochem2.tutkie.tut.ac.jp', 'taisuke', 'boku', 'daisuke', 'takahashi', 'institute', 'information', 'sciences', 'electronics', 'university', 'tsukuba', 'tsukuba', 'japan', 'taisuke', 'daisuke}@hpcs.is.tsukuba.ac.jp', 'abstract', 'conflex', 'g', 'grid', 'version', 'molecular', 'conformational', 'space', 'search', 'program', 'conflex', 'conflex', 'g', 'grid', 'rpc', 'system', 'omnirpc', 'paper', 'performance', 'conflex', 'g', 'grid', 'testbed', 'pc', 'clusters', 'order', 'conformation', 'large', 'bio', 'molecules', 'conflex', 'g', 'trial', 'structures', 'molecules', 'jobs', 'trial', 'structure', 'reliable', 'molecular', 'mechanics', 'method', 'grid', 'omnirpc', 'restricted', 'persistence', 'model', 'parametric', 'search', 'applications', 'model', 'initialization', 'procedure', 'rpc', 'module', 'module', 'time', 'invocation', 'initialization', 'procedure', 'unnecessary', 'communication', 'initialization', 'conflex', 'g', 'conflexg', 'performance', 'comparable', 'conflex', 'mpi', 'computing', 'resources', 'use', 'cluster', 'multiple', 'clusters', 'grid', 'experimental', 'result', 'conflex', 'g', 'speedup', 'times', 'case', 'molecule', 'molecule', 'large', 'number', 'atoms', 'trial', 'structure', 'optimization', 'significant', 'time', 'load', 'imbalance', 'optimization', 'time', 'trial', 'structure', 'performance', 'degradation', 'categories', 'subject', 'descriptors', 'computer', 'systems', 'organization', 'computercommunication', 'network', 'systems', 'computer', 'applications', 'physical', 'sciences', 'engineering', 'general', 'terms', 'design', 'performance', 'introduction', 'elucidation', 'stable', 'conformations', 'folding', 'process', 'proteins', 'fundamental', 'challenging', 'goals', 'life', 'science', 'common', 'secondary', 'structures', 'certain', 'types', 'helix', 'beta', 'strand', 'coil', 'precise', 'analysis', 'thousands', 'important', 'conformers', 'pico', 'second', 'order', 'analysis', 'conformational', 'interconversions', 'transition', 'states', 'potential', 'energy', 'surface', 'microsecond', 'order', 'investigation', 'folding', 'process', 'tertiary', 'structure', 'formations', 'concept', 'computational', 'grid', 'significant', 'interest', 'field', 'high', 'performance', 'network', 'computing', 'rapid', 'advances', 'wide', 'area', 'networking', 'technology', 'infrastructure', 'possible', 'large', 'scale', 'high', 'performance', 'computing', 'environments', 'computational', 'grids', 'dependable', 'consistent', 'pervasive', 'access', 'enormous', 'computational', 'resources', 'conflex', 'efficient', 'reliable', 'conformational', 'space', 'search', 'programs[1', 'program', 'parallelization', 'global', 'computing', 'performance', 'conflex', 'exploration', 'lower', 'energy', 'region', 'conformational', 'space', 'small', 'peptides', 'available', 'time', 'local', 'pc', 'cluster', 'trial', 'structure', 'optimization', 'conflex', 'molecular', 'mechanics', 'conformational', 'space', 'search', 'molecular', 'orbital', 'calculation', 'version', 'conflex', 'parallel', 'structure', 'optimization', 'processing', 'molecular', 'conformation', 'search', 'sufficient', 'improvement', 'speedup', 'method', 'high', 'polymers', 'live', 'organisms', 'hiv', 'protease', 'pc', 'cluster', 'insufficient', 'requirement', 'optimization', 'huge', 'number', 'trial', 'structures', 'vast', 'computer', 'resources', 'grid', 'computing', 'environment', 'paper', 'conflex', 'g',  ...
# C-3.key
# C-3.txt
# ['self', 'adaptive', 'applications', 'grid', 'gosia', 'wrzesinska', 'jason', 'maassen', 'henri', 'e.', 'bal', 'dept', 'computer', 'systems', 'vrije', 'universiteit', 'amsterdam', 'gosia', 'jason', 'bal}@cs.vu.nl', 'abstract', 'grids', 'heterogeneous', 'dynamic', 'important', 'problem', 'grid', 'computing', 'resource', 'selection', 'appropriate', 'resource', 'application', 'problem', 'adaptation', 'characteristics', 'grid', 'environment', 'solutions', 'problems', 'performance', 'model', 'application', 'models', 'complex', 'task', 'paper', 'approach', 'performance', 'models', 'application', 'set', 'resources', 'application', 'run', 'statistics', 'application', 'application', 'requirements', 'statistics', 'resource', 'application', 'approach', 'performance', 'bottlenecks', 'wan', 'links', 'slow', 'processors', 'significant', 'performance', 'improvements', 'approach', 'number', 'scenarios', 'typical', 'grid', 'categories', 'subject', 'descriptors', 'computer', 'communication', 'networks', 'systems', 'applications', 'c.4', 'performance', 'systems', 'measurement', 'techniques', 'techniques', 'general', 'terms', 'algorithms', 'measurement', 'performance', 'experimentation', 'introduction', 'recent', 'years', 'grid', 'computing', 'real', 'alternative', 'traditional', 'parallel', 'computing', 'grid', 'computational', 'power', 'possibility', 'large', 'problems', 'applications', 'multiple', 'sites', 'time', 'complexity', 'grid', 'environments', 'times', 'larger', 'traditional', 'parallel', 'machines', 'clusters', 'supercomputers', 'important', 'problem', 'resource', 'selection', 'set', 'compute', 'nodes', 'application', 'good', 'performance', 'traditional', 'homogeneous', 'parallel', 'environments', 'optimal', 'number', 'nodes', 'hard', 'problem', 'trial', 'error', 'fashion', 'grid', 'environment', 'problem', 'difficult', 'heterogeneity', 'resources', 'compute', 'nodes', 'speeds', 'quality', 'network', 'connections', 'low', 'latency', 'high', 'bandwidth', 'local', 'area', 'networks', 'lans', 'high', 'latency', 'low', 'bandwidth', 'wide', 'area', 'networks', 'wans', 'important', 'problem', 'performance', 'availability', 'grid', 'resources', 'time', 'network', 'links', 'compute', 'nodes', 'overloaded', 'compute', 'nodes', 'unavailable', 'crashes', 'higher', 'priority', 'application', 'new', 'better', 'resources', 'available', 'reasonable', 'performance', 'level', 'application', 'conditions', 'adaptation', 'problem', 'resource', 'selection', 'problem', 'resource', 'selection', 'phase', 'application', 'execution', 'regular', 'intervals', 'performance', 'problem', 'new', 'resources', 'available', 'approach', 'number', 'systems', 'resource', 'selection', 'application', 'runtime', 'resource', 'sets', 'set', 'shortest', 'runtime', 'execution', 'application', 'runtime', 'set', 'resources', 'knowledge', 'application', 'analytical', 'performance', 'model', 'model', 'difficult', 'expertise', 'application', 'programmers', 'paper', 'alternative', 'approach', 'adaptation', 'resource', 'selection', 'performance', 'model', 'application', 'set', 'resources', 'application', 'run', 'information', 'communication', 'times', 'idle', 'times', 'processors', 'statistics', 'resource', 'requirements', 'application', 'resource', 'application', 'compute', 'nodes', 'entire', 'clusters', 'adaptation', 'strategy', 'work', 'eager', 'et', 'al', 'efficiency', 'efficiency', 'application', 'lower', 'upper', 'threshold', 'theory', 'processors', 'thresholds', 'environment', 'major', 'advantage', 'approach', 'application', 'performance', 'different', 'situations', 'typical', 'grid', 'computing', 'cases', 'number', 'processors', 'degree', 'parallelism', 'application', 'degree', 'computation', 'computation', 'overloaded', 'resources', 'resources', 'poor', 'communication', 'lin']
# C-30.key
# C-30.txt
# ...
# H-5.key
# H-5.txt
# H-7.key
# H-7.txt
# ['efficient', 'bayesian', 'hierarchical', 'user', 'modeling', 'recommendation', 'systems', 'yi', 'zhang', 'jonathan', 'koren', 'school', 'engineering', 'university', 'california', 'santa', 'cruz', 'santa', 'cruz', 'usa', 'jonathan}@soe.ucsc.edu', 'abstract', 'content', 'personalized', 'recommendation', 'system', 'specific', 'profiles', 'user', 'feedback', 'information', 'individual', 'user"s', 'interest', 'system', 'millions', 'users', 'better', 'user', 'profile', 'new', 'user', 'user', 'little', 'feedback', 'information', 'users', 'use', 'bayesian', 'hierarchical', 'model', 'model', 'parameters', 'joint', 'data', 'likelihood', 'millions', 'users', 'expensive', 'algorithm', 'sparseness', 'data', 'ir', 'applications', 'paper', 'new', 'fast', 'learning', 'technique', 'large', 'number', 'individual', 'user', 'profiles', 'efficacy', 'efficiency', 'algorithm', 'theory', 'actual', 'user', 'data', 'netflix', 'movielens', 'categories', 'subject', 'descriptors', 'information', 'search', 'retrieval', 'information', 'general', 'terms', 'algorithms', 'introduction', 'personalization', 'future', 'web', 'great', 'success', 'industrial', 'applications', 'example', 'online', 'stores', 'amazon', 'netflix', 'recommendations', 'additional', 'products', 'services', 'user"s', 'history', 'recent', 'offerings', 'msn', 'yahoo', 'google', 'google', 'news', 'attention', 'potential', 'ability', 'user"s', 'interests', 'history', 'major', 'personalization', 'topic', 'information', 'retrieval', 'community', 'content', 'personal', 'recommendation', 'systems1', 'systems', 'user', 'specific', 'profiles', 'user', 'feedback', 'information', 'individual', 'user"s', 'interest', 'user', 'explicit', 'query', 'user', 'profiles', 'core', 'problem', 'systems', 'user', 'profile', 'classifier', 'document', 'relevant', 'user', 'regression', 'model', 'relevant', 'document', 'user', 'major', 'challenge', 'recommendation', 'personalization', 'system', 'profile', 'particular', 'user', 'low', 'quality', 'data', 'particular', 'user', 'small', 'cold', 'start', 'problem', 'new', 'user', 'poor', 'initial', 'performance', 'sufficient', 'feedback', 'user', 'reliable', 'user', 'profile', 'research', 'classification', 'accuracy', 'training', 'data', 'small', 'supervised', 'learning', 'approach', 'unlabeled', 'data', 'goal', 'approach', 'domain', 'knowledge', 'researchers', 'different', 'learning', 'algorithms', 'na¨ıvebayes', 'logistic', 'regression', 'svms', 'domain', 'knowledge', 'text', 'classifier', 'approach', 'training', 'data', 'resources', 'effectiveness', 'different', 'approaches', 'mixed', 'underlying', 'model', 'assumption', 'data', 'approach', 'recommendation', 'system', 'performance', 'particular', 'user', 'information', 'users', 'bayesian', 'hierarchical', 'modeling', 'approach', 'researchers', 'approach', 'user', 'specific', 'information', 'poor', 'initial', 'performance', 'user[27][25', 'order', 'bayesian', 'hierarchical', 'model', 'system', 'likely', 'model', 'parameters', 'data', 'mature', 'recommendation', 'system', 'millions', 'users', 'optimal', 'parameters', 'bayesian', 'hierarchical', 'model', 'expensive', 'thousands', 'millions', 'users', 'em', 'algorithm', 'technique', 'parameter', 'learning', 'simplicity', 'convergence', 'guarantee', 'content', 'recommendation', 'system', 'documents', 'high', 'dimensional', 'space', 'document', 'sparse', 'vector', 'careful', 'analysis', 'em', 'algorithm', 'scenario', 'section', 'em', 'tering', 'item', 'collaborative', 'filtering', 'paper', 'words', 'filtering', 'recommendation', 'algorithm', 'sparseness', 'input', 'variables', 'model', 'parameter', 'em', 'iteration', 'expensive', 'computational', 'complexity', 'm', 'number', 'users', 'k', 'number', 'dimensions', 'paper', 'standard', 'algorithm', 'improved', 'learning', 'algorithm', 'algorithm', 'basic', 'idea', 'numerical', 'solution', 'user', 'profile', 'parameters', 'analytical', 'solution', 'parameters']
# H-8.key
# H-8.txt
# ['robust', 'test', 'collections', 'retrieval', 'evaluation', 'ben', 'carterette', 'center', 'intelligent', 'information', 'retrieval', 'computer', 'science', 'department', 'university', 'massachusetts', 'amherst', 'amherst', 'ma', 'abstract', 'low', 'cost', 'methods', 'relevance', 'judgments', 'boon', 'researchers', 'new', 'retrieval', 'tasks', 'topics', 'resources', 'thousands', 'judgments', 'judgments', 'useful', 'time', 'evaluation', 'clear', 'new', 'systems', 'work', 'judgments', 'reusable', 'confidence', 'evaluation', 'new', 'systems', 'set', 'relevance', 'judgments', 'method', 'set', 'relevance', 'judgments', 'relevance', 'estimates', 'additional', 'assessor', 'effort', 'method', 'guarantees', 'reusability', 'judgments', 'topic', 'systems', 'larger', 'set', 'systems', 'smallest', 'sets', 'judgments', 'useful', 'evaluation', 'new', 'systems', 'categories', 'subject', 'descriptors', 'information', 'storage', 'retrieval', 'systems', 'software', 'performance', 'evaluation', 'general', 'terms', 'experimentation', 'measurement', 'reliability', 'introduction', 'information', 'retrieval', 'researcher', 'new', 'retrieval', 'task', 'system', 'task', 'task', 'new', 'unlikely', 'extant', 'relevance', 'judgments', 'time', 'resources', 'document', 'document', 'documents', 'informative', 'reasonable', 'degree', 'confidence', 'conclusions', 'new', 'system', 'research', 'group', 'system', 'task', 'original', 'judgments', 'relevance', 'judgments', 'evaluation', 'important', 'aspect', 'information', 'retrieval', 'research', 'solved', 'problem', 'retrieval', 'tasks', 'impossible', 'relevance', 'document', 'solution', 'nist', 'trec', 'text', 'retrieval', 'conference', 'pooling', 'method', 'systems', 'documents', 'pool', 'document', 'pool', 'method', 'large', 'sets', 'judgments', 'reusable', 'training', 'new', 'systems', 'pool', 'solution', 'adequate', 'hypothetical', 'researcher', 'pooling', 'method', 'thousands', 'relevance', 'judgments', 'hours', 'annotator', 'time', 'result', 'slew', 'recent', 'papers', 'annotator', 'effort', 'test', 'collections', 'cormack', 'et', 'al', 'zobel', 'sanderson', 'joho', 'carterette', 'et', 'al', 'aslam', 'et', 'al', 'judgments', 'methods', 'evaluation', 'new', 'set', 'systems', 'hypothetical', 'resesarcher', 'relevance', 'judgments', 'reusable', 'previous', 'work', 'reusability', 'accuracy', 'set', 'relevance', 'judgments', 'unseen', 'systems', 'right', 'time', 'rank', 'correlation', 'numbers', 'predictive', 'power', 'systems', 'likely', 'wrong', 'confident', 'careful', 'definition', 'reusability', 'question', 'reusability', 'new', 'systems', 'malicious', 'adversary', 'new', 'ranked', 'list', 'documents', 'real', 'question', 'confidence', 'evaluations', 'estimates', 'confidence', 'confidence', 'high', 'systems', 'judgments', 'order', 'confidence', 'set', 'judgments', 'small', 'reusable', 'degree', 'small', 'reusable', 'test', 'collections', 'huge', 'impact', 'information', 'retrieval', 'research', 'research', 'groups', 'able', 'relevance', 'judgments', 'house', 'pilot', 'studies', 'new', 'tasks', 'new', 'topics', 'data', 'available', 'researchers', 'time', 'robust', 'evaluation', 'intuitive', 'definition', 'reusability', 'collection', 'reusable', 'estimates', 'confidence', 'evaluation', 'relevance', 'judgments', 'example', 'confidence', 'system', 'better', 'system', 'b', 'chance', 'assessment', 'relative', 'quality', 'systems', 'documents', 'evaluation', 'robust']
# H-9.key
# H-9.txt
# ['web', 'search', 'logs', 'search', 'results', 'xuanhui', 'wang', 'department', 'computer', 'science', 'university', 'illinois', 'urbana', 'champaign', 'urbana', 'il', 'chengxiang', 'zhai', 'department', 'computer', 'science', 'university', 'illinois', 'urbana', 'champaign', 'urbana', 'il', 'abstract', 'effective', 'organization', 'search', 'results', 'critical', 'utility', 'search', 'engine', 'clustering', 'search', 'results', 'effective', 'way', 'search', 'results', 'user', 'relevant', 'documents', 'deficiencies', 'approach', 'clusters', 'interesting', 'aspects', 'topic', 'user"s', 'perspective', 'cluster', 'labels', 'informative', 'user', 'right', 'cluster', 'paper', 'deficiencies', 'interesting', 'aspects', 'topic', 'web', 'search', 'logs', 'search', 'results', 'meaningful', 'cluster', 'labels', 'query', 'words', 'users', 'method', 'commercial', 'search', 'engine', 'log', 'data', 'traditional', 'methods', 'clustering', 'search', 'results', 'method', 'better', 'result', 'organization', 'meaningful', 'labels', 'categories', 'subject', 'descriptors', 'information', 'search', 'retrieval', 'clustering', 'search', 'process', 'general', 'terms', 'algorithm', 'experimentation', 'introduction', 'utility', 'search', 'engine', 'multiple', 'factors', 'primary', 'factor', 'soundness', 'retrieval', 'model', 'ranking', 'function', 'present', 'search', 'results', 'important', 'factor', 'utility', 'search', 'engine', 'vast', 'literature', 'retrieval', 'models', 'little', 'research', 'effectiveness', 'search', 'result', 'organization', 'common', 'strategy', 'search', 'results', 'simple', 'ranked', 'list', 'presentation', 'strategy', 'reasonable', 'non', 'ambiguous', 'homogeneous', 'search', 'results', 'general', 'search', 'results', 'good', 'user', 'relevant', 'documents', 'results', 'search', 'results', 'diverse', 'ambiguity', 'multiple', 'aspects', 'topic', 'case', 'web', 'search', 'ranked', 'list', 'presentation', 'effective', 'case', 'better', 'search', 'results', 'clusters', 'user', 'particular', 'interesting', 'group', 'example', 'results', 'page', 'google', 'ambiguous', 'query', 'jaguar', 'dec', '2nd', 'different', 'senses', 'jaguar', 'car', 'animal', 'software', 'sports', 'team', 'refined', 'query', 'jaguar', 'team', 'picture', 'results', 'ambiguous', 'different', 'jaguar', 'teams', 'wrestling', 'team', 'jaguar', 'car', 'team', 'southwestern', 'college', 'jaguar', 'softball', 'team', 'jacksonville', 'jaguar', 'football', 'team', 'user', 'place', 'jaguar', 'software', 'query', 'download', 'jaguar', 'effective', 'results', 'jaguar', 'brochure', 'jaguar', 'wallpaper', 'jaguar', 'dvd', 'examples', 'clustering', 'view', 'search', 'results', 'useful', 'user', 'simple', 'ranked', 'list', 'clustering', 'useful', 'search', 'results', 'poor', 'case', 'user', 'long', 'list', 'relevant', 'document', 'primary', 'alternative', 'strategy', 'search', 'results', 'clustering', 'search', 'results', 'general', 'idea', 'work', 'clustering', 'set', 'topranked', 'search', 'results', 'results', 'natural', 'clusters', 'different', 'subtopics', 'general', 'query', 'topic', 'label', 'cluster', 'user', 'labels', 'cluster', 'strategy', 'useful', 'simple', 'ranked', 'list', 'presentation', 'studies', 'clustering', 'strategy', 'deficiencies', 'clusters', 'way', 'interesting', 'aspects', 'topic', 'user"s', 'perspective', 'example', 'users', 'interested', 'phone', 'codes', 'zip', 'codes', 'query', 'area', 'codes', 'clusters', 'current', 'methods', 'results', 'local', 'codes', 'international', 'codes', 'clusters', 'useful', 'users', 'best', 'cluster', 'low', 'precision', 'cluster', 'labels', 'informative', 'user', 'right', 'cluster', 'reasons', 'problem', 'clusters', 'user"s', 'interests', 'label']
# I-1.key
# I-1.txt
# ['tasks', 'bdi', 'agents', 'john', 'thangarajah', 'james', 'harland', 'rmit', 'university', 'melbourne', 'australia', 'johthan', 'jah}@cs.rmit.edu.au', 'david', 'morley', 'neil', 'yorke', 'smith', 'artificial', 'intelligence', 'center', 'sri', 'international', 'menlo', 'park', 'u.s.a', 'abstract', 'intelligent', 'agents', 'dynamic', 'environments', 'able', 'unsuccessful', 'tasks', 'plans', 'addition', 'agents', 'able', 'rational', 'decisions', 'appropriate', 'course', 'action', 'task', 'plan', 'result', 'agent"s', 'deliberations', 'request', 'agent', 'paper', 'incorporation', 'aborts', 'bdi', 'style', 'architecture', 'conditions', 'task', 'plan', 'appropriate', 'consequences', 'decision', 'plan', 'optional', 'abort', 'method', 'analogous', 'failure', 'method', 'agent', 'programming', 'languages', 'operational', 'semantics', 'execution', 'cycle', 'presence', 'aborts', 'abstract', 'agent', 'language', 'bdi', 'execution', 'model', 'attention', 'particular', 'agent', 'system', 'jack', 'jadex', 'jason', 'spark', 'key', 'technical', 'challenge', 'presence', 'parallel', 'execution', 'threads', 'sub', 'tasks', 'agent', 'abort', 'methods', 'plan', 'appropriate', 'sequence', 'categories', 'subject', 'descriptors', 'artificial', 'intelligence', 'artificial', 'intelligence', 'intelligent', 'agents', 'general', 'terms', 'design', 'reliability', 'theory', 'introduction', 'intelligent', 'agents', 'complex', 'dynamic', 'environments', 'air', 'traffic', 'control', 'robot', 'navigation', 'success', 'particular', 'action', 'plan', 'failure', 'fundamental', 'agent', 'programming', 'important', 'element', 'agent', 'characteristics', 'robustness', 'flexibility', 'persistence', 'agent', 'architectures', 'belief', 'desire', 'intention', 'bdi', 'model', 'properties', 'interactions', 'beliefs', 'goals', 'general', 'agent', 'particular', 'set', 'tasks', 'number', 'plans', 'failures', 'choice', 'plans', 'alternative', 'plans', 'particular', 'task', 'scheduling', 'tasks', 'resource', 'constraints', 'tasks', 'decision', 'likelihood', 'success', 'failures', 'number', 'reasons', 'possible', 'advance', 'complexity', 'system', 'changes', 'environment', 'earlier', 'decisions', 'need', 'deliberation', 'tasks', 'plans', 'failure', 'deliberation', 'agent"s', 'execution', 'cycle', 'failure', 'important', 'capability', 'intelligent', 'agent', 'able', 'particular', 'task', 'plan', 'decision', 'internal', 'deliberation', 'agent', 'task', 'task', 'higher', 'priority', 'external', 'factor', 'agent', 'commitment', 'change', 'environment', 'task', 'plan', 'distinct', 'failure', 'failure', 'inability', 'need', 'example', 'reasonable', 'response', 'failure', 'contrast', 'ability', 'need', 'failure', 'potential', 'sub', 'plans', 'different', 'complexities', 'failure', 'multiple', 'concurrent', 'sub', 'plans', 'abort', 'failure', 'parallel', 'sibling', 'plans', 'failure', 'considerable', 'work', 'plan', 'failures', 'resource', 'conflicts', 'agent', 'systems', 'notion', 'failure', 'handling', 'little', 'work', 'development', 'techniques', 'simple', 'dropping', 'plans', 'tasks', 'consequence', 'agent', 'systems', 'limited', 'treatment', 'situation', 'branch', 'parallel', 'construct', 'tasks', 'goals', 'certain', 'state', 'world', 'task', 'goal', 'state', 'task', 'goal', 'task', 'state', 'world', 'view', 'task', 'goals', 'rps', 'c', 'ifaamas', 'fails', 'common', 'approaches', 'branch', 'completion', 'un']
# I-10.key

# %%
# show output
for service in services:
  print("Service: " + service.name)

  service.total_precision /= total_docs
  service.total_recall /= total_docs
  service.total_fmeasure = 2 * service.total_precision * service.total_recall / (service.total_precision + service.total_recall)

  print('total docs: ' + str(round(total_docs, 5)))
  print('total precision: ' + str(round(service.total_precision, 5)))
  print('total recall: ' + str(round(service.total_recall, 5)))
  print('total f1-score: ' + str(round(service.total_fmeasure, 5)))
# Out:
# Service: spacy
# total docs: 98
# total precision: 0.04603
# total recall: 0.32893
# total f1-score: 0.08075
# Service: microsoft
# total docs: 98
# total precision: 0.00305
# total recall: 0.01522
# total f1-score: 0.00508
# Service: rake
# total docs: 98
# total precision: 0.01384
# total recall: 0.13183
# total f1-score: 0.02504
# Service: spacy_rake
# total docs: 98
# total precision: 0.04594
# total recall: 0.32986
# total f1-score: 0.08065
